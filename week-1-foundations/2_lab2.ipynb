# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

question = gemini.chat.completions.create(
    model=model_name,
    messages=messages,
)
question = question.choices[0].message.content
print(question)
# Out:
# Imagine a society where all basic material needs are met by fully autonomous AI, and human labor is no longer required for survival or comfort. Describe the most likely *unexpected* negative consequence of such a scenario, detailing both its psychological and societal manifestations, and propose a nuanced, non-obvious social innovation that could mitigate it.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
# model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# The premise of a society where all basic material needs are met by fully autonomous AI, freeing humanity from labor, initially paints a utopian picture. However, the most likely *unexpected* negative consequence would not be technological rebellion or resource scarcity (as AI handles it), but rather a profound and pervasive **Erosion of Earned Value and Meaningful Struggle.**
#
# ## The Erosion of Earned Value and Meaningful Struggle
#
# Humans are not merely consumers; we are builders, problem-solvers, and strivers. Our psychology is deeply wired for the cycle of challenge, effort, perseverance, and achievement. When this fundamental cycle is removed, replaced by effortless provision, it disrupts the very mechanisms by which we derive a sense of competence, identity, and value.
#
# **Psychological Manifestations:**
#
# 1.  **Pervasive Anhedonia and Apathy:** While the absence of struggle might seem ideal, it paradoxically leads to an inability to fully experience joy or satisfaction. If everything is provided instantly and without effort, nothing feels *earned*. The dopamine rush of solving a difficult problem, the pride in mastering a skill, the satisfaction of contributing to a tangible outcome – these become rare or non-existent. This can lead to a widespread state of anhedonia, where even pleasurable activities feel hollow, and a profound apathy sets in, rendering individuals indifferent to pursuits that once brought meaning.
# 2.  **Identity Crisis and Existential Drift:** A significant part of human identity is often tied to what we *do* – our work, our contributions, our unique skills. When these are rendered obsolete, individuals struggle to define themselves. "What am I, if not a worker, a provider, a creator?" This existential void leads to feelings of uselessness, purposelessness, and a profound drift, as people lack an anchor for their self-concept.
# 3.  **Surge in Maladaptive Escapism:** To fill the void of meaningful engagement and combat the crushing boredom and anhedonia, society would likely see a massive surge in maladaptive coping mechanisms. This could range from hyper-addictive virtual realities and sensory experiences (designed to simulate struggle or achievement) to widespread substance abuse, extreme hedonism, and even a rise in self-destructive behaviors, as people seek any form of intense sensation to feel "alive" or escape the monotony of effortless existence.
# 4.  **Loss of Resilience and Grit:** Without facing adversity, humans lose the capacity for resilience. The ability to push through difficulties, to adapt, to learn from failure – these muscles atrophy. When even minor inconveniences occur (and some will, even in a post-scarcity world), people would lack the psychological tools to cope, leading to heightened anxiety, fragility, and emotional breakdowns.
#
# **Societal Manifestations:**
#
# 1.  **Social Fragmentation and Trivialization of Relationships:** Shared labor and collective goals are powerful social glues. When these are gone, society risks fragmenting into isolated individuals or groups pursuing increasingly niche, often trivial, interests. Relationships might become superficial, based more on shared consumption or fleeting entertainment than on mutual support, shared struggle, or collaborative creation.
# 2.  **Stagnation of Human Innovation and Creativity (Beyond the Trivial):** While AI handles all "necessary" innovation, the *human* drive for discovery, artistic creation, and intellectual pursuit could wane. Why dedicate years to a difficult scientific problem or a complex art form if its outcome is not "needed" and provides no unique societal status beyond fleeting applause? Innovation might become purely aesthetic or escapist, lacking the deeper societal impact driven by necessity or the human desire to overcome genuine obstacles.
# 3.  **Emergence of Artificial Hierarchies and "Curated Controversies":** In the absence of traditional markers of status (wealth, achievement, contribution), new, often arbitrary, hierarchies might emerge. These could be based on curated popularity within virtual networks, the ability to consume the most novel experiences, or even the creation of artificial "struggles" or "controversies" to generate engagement and a sense of importance. Society might become obsessed with manufactured drama, gossip, or performative outrage, seeking to create friction where none naturally exists.
# 4.  **Loss of Collective Purpose and Moral Decay:** A society without collective purpose risks losing its moral compass. If everyone's needs are met and there's no inherent requirement for contribution, what motivates empathy, altruism, or adherence to ethical principles? Why sacrifice or compromise for the greater good if "the greater good" is handled by AI, and individual struggle yields no tangible personal or societal reward?
#
# ## Nuanced, Non-Obvious Social Innovation: The "Synergistic Curation of Existential Challenges" (SCEC)
#
# Rather than trying to recreate work or force purpose, SCEC seeks to *engineer environments of chosen, meaningful struggle* that leverage AI to enhance the *human experience* of overcoming challenges, not to automate the challenges away entirely.
#
# **Core Concept:** SCEC is a globally interconnected, AI-managed framework that **identifies, refines, and presents "existential challenges"** tailored to human capabilities and aspirations, allowing individuals and communities to voluntarily embark on demanding, multi-generational projects with profound (though often non-material) human value.
#
# **How it Works:**
#
# 1.  **AI as the "Chief Curator of Hardship":** The central AI's role isn't just to provide comfort, but to *intelligently identify and structure genuinely difficult, multi-faceted problems* that require uniquely human attributes (creativity, intuition, ethical reasoning, sustained emotional resilience, inter-human collaboration) to address. These aren't problems AI *can't* solve, but problems where the *human process of solving them* is the ultimate goal and value.
#     *   *Examples:* Designing a global system for interspecies communication and diplomacy, rehabilitating an extinct ecosystem using only pre-industrial tools and knowledge (for the learning and process), developing an entirely new philosophical framework for pan-sentient rights, pioneering deep-space exploration missions where human presence and decision-making are paramount, or creating vast, collaborative art forms that take centuries to complete.
#
# 2.  **"Merit-Based Access to Difficulty":** Participation in these curated challenges is highly prestigious and competitive, not for material gain, but for the inherent value of the struggle, the opportunity for deep learning, and the social recognition of contribution. Individuals or teams apply, presenting their unique skills, passions, and commitments. AI assists in matching individuals to challenges where they can genuinely thrive and contribute, acting as a sophisticated "purpose-matchmaker."
#
# 3.  **Non-Monetary, "Reputational Capital" Rewards:** The "rewards" are entirely non-material. They include:
#     *   **Profound Personal Growth:** The inherent satisfaction of mastering complex skills, enduring hardship, and achieving difficult goals.
#     *   **Societal Reverence:** "Challenge-completers" or "Struggle-Pioneers" gain immense social capital, respect, and influence. This is not about celebrity, but a deep, community-wide acknowledgment of their sustained effort and unique contribution to humanity's collective narrative.
#     *   **Access to Deeper Challenges:** Successful participation unlocks access to even more complex, multi-generational, and philosophically profound projects.
#     *   **Historical Legacy:** Detailed, AI-curated narratives of each challenge and its human participants are preserved in a global historical archive, ensuring their efforts contribute to humanity's ongoing story.
#
# 4.  **AI-Enhanced Scaffolding, Not Solutions:** The AI provides tools for research, simulation, logistics, and safety, but it explicitly *refrains* from solving the core challenge. Instead, it acts as a mentor, a knowledge base, and a "difficulty calibrator," ensuring the challenges remain just beyond easy reach, requiring genuine human ingenuity and perseverance. It might prevent catastrophic failures but never trivializes the human effort.
#
# 5.  **Re-framing "Work" as "Existential Engagement":** This system shifts the societal understanding of "work" from labor for survival to a *chosen engagement with the limits of human potential*. It instills a new form of "earned value" – not material wealth, but the value derived from meaningful struggle, personal growth, and contributing to the enrichment of the human story itself.
#
# **Mitigation Effectiveness:**
#
# *   **Combats Anhedonia/Apathy:** By reintroducing the cycle of challenge and achievement, individuals regain a vital source of intrinsic motivation and joy. The *earned* satisfaction of overcoming a difficult, self-chosen obstacle becomes paramount.
# *   **Restores Identity and Purpose:** Provides clear avenues for individuals to define themselves through their chosen struggles and contributions, fostering a sense of self-worth and direction.
# *   **Channels Escapism into Productivity:** Instead of succumbing to maladaptive escapism, individuals can find profound engagement and intensity within the framework of real, albeit non-materially necessary, challenges.
# *   **Rebuilds Resilience:** Actively participating in structured challenges rebuilds psychological resilience and grit, preparing individuals for unexpected difficulties.
# *   **Fosters Social Cohesion:** Communities form around shared struggles, collaborative projects, and mutual respect for those engaged in difficult endeavors, strengthening social bonds beyond superficial connections.
# *   **Drives Human-Centric Innovation:** While AI handles material innovation, SCEC directs human ingenuity towards areas unique to our species: philosophical depth, artistic expression, ethical development, and the expansion of human consciousness itself.
#
# This "Synergistic Curation of Existential Challenges" acknowledges that while AI can remove physical toil, it cannot remove the human need for purpose, meaning, and the profound satisfaction that comes from *earning* one's place in the universe, one difficult, chosen struggle at a time.

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)
# Out:
# ['gemini-2.5-flash']
# ['The premise of a society where all basic material needs are met by fully autonomous AI, freeing humanity from labor, initially paints a utopian picture. However, the most likely *unexpected* negative consequence would not be technological rebellion or resource scarcity (as AI handles it), but rather a profound and pervasive **Erosion of Earned Value and Meaningful Struggle.**\n\n## The Erosion of Earned Value and Meaningful Struggle\n\nHumans are not merely consumers; we are builders, problem-solvers, and strivers. Our psychology is deeply wired for the cycle of challenge, effort, perseverance, and achievement. When this fundamental cycle is removed, replaced by effortless provision, it disrupts the very mechanisms by which we derive a sense of competence, identity, and value.\n\n**Psychological Manifestations:**\n\n1.  **Pervasive Anhedonia and Apathy:** While the absence of struggle might seem ideal, it paradoxically leads to an inability to fully experience joy or satisfaction. If everything is provided instantly and without effort, nothing feels *earned*. The dopamine rush of solving a difficult problem, the pride in mastering a skill, the satisfaction of contributing to a tangible outcome – these become rare or non-existent. This can lead to a widespread state of anhedonia, where even pleasurable activities feel hollow, and a profound apathy sets in, rendering individuals indifferent to pursuits that once brought meaning.\n2.  **Identity Crisis and Existential Drift:** A significant part of human identity is often tied to what we *do* – our work, our contributions, our unique skills. When these are rendered obsolete, individuals struggle to define themselves. "What am I, if not a worker, a provider, a creator?" This existential void leads to feelings of uselessness, purposelessness, and a profound drift, as people lack an anchor for their self-concept.\n3.  **Surge in Maladaptive Escapism:** To fill the void of meaningful engagement and combat the crushing boredom and anhedonia, society would likely see a massive surge in maladaptive coping mechanisms. This could range from hyper-addictive virtual realities and sensory experiences (designed to simulate struggle or achievement) to widespread substance abuse, extreme hedonism, and even a rise in self-destructive behaviors, as people seek any form of intense sensation to feel "alive" or escape the monotony of effortless existence.\n4.  **Loss of Resilience and Grit:** Without facing adversity, humans lose the capacity for resilience. The ability to push through difficulties, to adapt, to learn from failure – these muscles atrophy. When even minor inconveniences occur (and some will, even in a post-scarcity world), people would lack the psychological tools to cope, leading to heightened anxiety, fragility, and emotional breakdowns.\n\n**Societal Manifestations:**\n\n1.  **Social Fragmentation and Trivialization of Relationships:** Shared labor and collective goals are powerful social glues. When these are gone, society risks fragmenting into isolated individuals or groups pursuing increasingly niche, often trivial, interests. Relationships might become superficial, based more on shared consumption or fleeting entertainment than on mutual support, shared struggle, or collaborative creation.\n2.  **Stagnation of Human Innovation and Creativity (Beyond the Trivial):** While AI handles all "necessary" innovation, the *human* drive for discovery, artistic creation, and intellectual pursuit could wane. Why dedicate years to a difficult scientific problem or a complex art form if its outcome is not "needed" and provides no unique societal status beyond fleeting applause? Innovation might become purely aesthetic or escapist, lacking the deeper societal impact driven by necessity or the human desire to overcome genuine obstacles.\n3.  **Emergence of Artificial Hierarchies and "Curated Controversies":** In the absence of traditional markers of status (wealth, achievement, contributio ...

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")
# Out:
# Competitor: gemini-2.5-flash
#
# The premise of a society where all basic material needs are met by fully autonomous AI, freeing humanity from labor, initially paints a utopian picture. However, the most likely *unexpected* negative consequence would not be technological rebellion or resource scarcity (as AI handles it), but rather a profound and pervasive **Erosion of Earned Value and Meaningful Struggle.**
#
# ## The Erosion of Earned Value and Meaningful Struggle
#
# Humans are not merely consumers; we are builders, problem-solvers, and strivers. Our psychology is deeply wired for the cycle of challenge, effort, perseverance, and achievement. When this fundamental cycle is removed, replaced by effortless provision, it disrupts the very mechanisms by which we derive a sense of competence, identity, and value.
#
# **Psychological Manifestations:**
#
# 1.  **Pervasive Anhedonia and Apathy:** While the absence of struggle might seem ideal, it paradoxically leads to an inability to fully experience joy or satisfaction. If everything is provided instantly and without effort, nothing feels *earned*. The dopamine rush of solving a difficult problem, the pride in mastering a skill, the satisfaction of contributing to a tangible outcome – these become rare or non-existent. This can lead to a widespread state of anhedonia, where even pleasurable activities feel hollow, and a profound apathy sets in, rendering individuals indifferent to pursuits that once brought meaning.
# 2.  **Identity Crisis and Existential Drift:** A significant part of human identity is often tied to what we *do* – our work, our contributions, our unique skills. When these are rendered obsolete, individuals struggle to define themselves. "What am I, if not a worker, a provider, a creator?" This existential void leads to feelings of uselessness, purposelessness, and a profound drift, as people lack an anchor for their self-concept.
# 3.  **Surge in Maladaptive Escapism:** To fill the void of meaningful engagement and combat the crushing boredom and anhedonia, society would likely see a massive surge in maladaptive coping mechanisms. This could range from hyper-addictive virtual realities and sensory experiences (designed to simulate struggle or achievement) to widespread substance abuse, extreme hedonism, and even a rise in self-destructive behaviors, as people seek any form of intense sensation to feel "alive" or escape the monotony of effortless existence.
# 4.  **Loss of Resilience and Grit:** Without facing adversity, humans lose the capacity for resilience. The ability to push through difficulties, to adapt, to learn from failure – these muscles atrophy. When even minor inconveniences occur (and some will, even in a post-scarcity world), people would lack the psychological tools to cope, leading to heightened anxiety, fragility, and emotional breakdowns.
#
# **Societal Manifestations:**
#
# 1.  **Social Fragmentation and Trivialization of Relationships:** Shared labor and collective goals are powerful social glues. When these are gone, society risks fragmenting into isolated individuals or groups pursuing increasingly niche, often trivial, interests. Relationships might become superficial, based more on shared consumption or fleeting entertainment than on mutual support, shared struggle, or collaborative creation.
# 2.  **Stagnation of Human Innovation and Creativity (Beyond the Trivial):** While AI handles all "necessary" innovation, the *human* drive for discovery, artistic creation, and intellectual pursuit could wane. Why dedicate years to a difficult scientific problem or a complex art form if its outcome is not "needed" and provides no unique societal status beyond fleeting applause? Innovation might become purely aesthetic or escapist, lacking the deeper societal impact driven by necessity or the human desire to overcome genuine obstacles.
# 3.  **Emergence of Artificial Hierarchies and "Curated Controversies":** In the absence of traditional markers of status (wealth, achievement, contribution), new, often arbitrary, hierarchies might emerge. These could be based on curated popularity within virtual networks, the ability to consume the most novel experiences, or even the creation of artificial "struggles" or "controversies" to generate engagement and a sense of importance. Society might become obsessed with manufactured drama, gossip, or performative outrage, seeking to create friction where none naturally exists.
# 4.  **Loss of Collective Purpose and Moral Decay:** A society without collective purpose risks losing its moral compass. If everyone's needs are met and there's no inherent requirement for contribution, what motivates empathy, altruism, or adherence to ethical principles? Why sacrifice or compromise for the greater good if "the greater good" is handled by AI, and individual struggle yields no tangible personal or societal reward?
#
# ## Nuanced, Non-Obvious Social Innovation: The "Synergistic Curation of Existential Challenges" (SCEC)
#
# Rather than trying to recreate work or force purpose, SCEC seeks to *engineer environments of chosen, meaningful struggle* that leverage AI to enhance the *human experience* of overcoming challenges, not to automate the challenges away entirely.
#
# **Core Concept:** SCEC is a globally interconnected, AI-managed framework that **identifies, refines, and presents "existential challenges"** tailored to human capabilities and aspirations, allowing individuals and communities to voluntarily embark on demanding, multi-generational projects with profound (though often non-material) human value.
#
# **How it Works:**
#
# 1.  **AI as the "Chief Curator of Hardship":** The central AI's role isn't just to provide comfort, but to *intelligently identify and structure genuinely difficult, multi-faceted problems* that require uniquely human attributes (creativity, intuition, ethical reasoning, sustained emotional resilience, inter-human collaboration) to address. These aren't problems AI *can't* solve, but problems where the *human process of solving them* is the ultimate goal and value.
#     *   *Examples:* Designing a global system for interspecies communication and diplomacy, rehabilitating an extinct ecosystem using only pre-industrial tools and knowledge (for the learning and process), developing an entirely new philosophical framework for pan-sentient rights, pioneering deep-space exploration missions where human presence and decision-making are paramount, or creating vast, collaborative art forms that take centuries to complete.
#
# 2.  **"Merit-Based Access to Difficulty":** Participation in these curated challenges is highly prestigious and competitive, not for material gain, but for the inherent value of the struggle, the opportunity for deep learning, and the social recognition of contribution. Individuals or teams apply, presenting their unique skills, passions, and commitments. AI assists in matching individuals to challenges where they can genuinely thrive and contribute, acting as a sophisticated "purpose-matchmaker."
#
# 3.  **Non-Monetary, "Reputational Capital" Rewards:** The "rewards" are entirely non-material. They include:
#     *   **Profound Personal Growth:** The inherent satisfaction of mastering complex skills, enduring hardship, and achieving difficult goals.
#     *   **Societal Reverence:** "Challenge-completers" or "Struggle-Pioneers" gain immense social capital, respect, and influence. This is not about celebrity, but a deep, community-wide acknowledgment of their sustained effort and unique contribution to humanity's collective narrative.
#     *   **Access to Deeper Challenges:** Successful participation unlocks access to even more complex, multi-generational, and philosophically profound projects.
#     *   **Historical Legacy:** Detailed, AI-curated narratives of each challenge and its human participants are preserved in a global historical archive, ensuring their efforts contribute to humanity's ongoing story.
#
# 4.  **AI-Enhanced Scaffolding, Not Solutions:** The AI provides tools for research, simulation, logistics, and safety, but it explicitly *refrains* from solving the core challenge. Instead, it acts as a mentor, a knowledge base, and a "difficulty calibrator," ensuring the challenges remain just beyond easy reach, requiring genuine human ingenuity and perseverance. It might prevent catastrophic failures but never trivializes the human effort.
#
# 5.  **Re-framing "Work" as "Existential Engagement":** This system shifts the societal understanding of "work" from labor for survival to a *chosen engagement with the limits of human potential*. It instills a new form of "earned value" – not material wealth, but the value derived from meaningful struggle, personal growth, and contributing to the enrichment of the human story itself.
#
# **Mitigation Effectiveness:**
#
# *   **Combats Anhedonia/Apathy:** By reintroducing the cycle of challenge and achievement, individuals regain a vital source of intrinsic motivation and joy. The *earned* satisfaction of overcoming a difficult, self-chosen obstacle becomes paramount.
# *   **Restores Identity and Purpose:** Provides clear avenues for individuals to define themselves through their chosen struggles and contributions, fostering a sense of self-worth and direction.
# *   **Channels Escapism into Productivity:** Instead of succumbing to maladaptive escapism, individuals can find profound engagement and intensity within the framework of real, albeit non-materially necessary, challenges.
# *   **Rebuilds Resilience:** Actively participating in structured challenges rebuilds psychological resilience and grit, preparing individuals for unexpected difficulties.
# *   **Fosters Social Cohesion:** Communities form around shared struggles, collaborative projects, and mutual respect for those engaged in difficult endeavors, strengthening social bonds beyond superficial connections.
# *   **Drives Human-Centric Innovation:** While AI handles material innovation, SCEC directs human ingenuity towards areas unique to our species: philosophical depth, artistic expression, ethical development, and the expansion of human consciousness itself.
#
# This "Synergistic Curation of Existential Challenges" acknowledges that while AI can remove physical toil, it cannot remove the human need for purpose, meaning, and the profound satisfaction that comes from *earning* one's place in the universe, one difficult, chosen struggle at a time.

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)
# Out:
# # Response from competitor 1
#
# The premise of a society where all basic material needs are met by fully autonomous AI, freeing humanity from labor, initially paints a utopian picture. However, the most likely *unexpected* negative consequence would not be technological rebellion or resource scarcity (as AI handles it), but rather a profound and pervasive **Erosion of Earned Value and Meaningful Struggle.**
#
# ## The Erosion of Earned Value and Meaningful Struggle
#
# Humans are not merely consumers; we are builders, problem-solvers, and strivers. Our psychology is deeply wired for the cycle of challenge, effort, perseverance, and achievement. When this fundamental cycle is removed, replaced by effortless provision, it disrupts the very mechanisms by which we derive a sense of competence, identity, and value.
#
# **Psychological Manifestations:**
#
# 1.  **Pervasive Anhedonia and Apathy:** While the absence of struggle might seem ideal, it paradoxically leads to an inability to fully experience joy or satisfaction. If everything is provided instantly and without effort, nothing feels *earned*. The dopamine rush of solving a difficult problem, the pride in mastering a skill, the satisfaction of contributing to a tangible outcome – these become rare or non-existent. This can lead to a widespread state of anhedonia, where even pleasurable activities feel hollow, and a profound apathy sets in, rendering individuals indifferent to pursuits that once brought meaning.
# 2.  **Identity Crisis and Existential Drift:** A significant part of human identity is often tied to what we *do* – our work, our contributions, our unique skills. When these are rendered obsolete, individuals struggle to define themselves. "What am I, if not a worker, a provider, a creator?" This existential void leads to feelings of uselessness, purposelessness, and a profound drift, as people lack an anchor for their self-concept.
# 3.  **Surge in Maladaptive Escapism:** To fill the void of meaningful engagement and combat the crushing boredom and anhedonia, society would likely see a massive surge in maladaptive coping mechanisms. This could range from hyper-addictive virtual realities and sensory experiences (designed to simulate struggle or achievement) to widespread substance abuse, extreme hedonism, and even a rise in self-destructive behaviors, as people seek any form of intense sensation to feel "alive" or escape the monotony of effortless existence.
# 4.  **Loss of Resilience and Grit:** Without facing adversity, humans lose the capacity for resilience. The ability to push through difficulties, to adapt, to learn from failure – these muscles atrophy. When even minor inconveniences occur (and some will, even in a post-scarcity world), people would lack the psychological tools to cope, leading to heightened anxiety, fragility, and emotional breakdowns.
#
# **Societal Manifestations:**
#
# 1.  **Social Fragmentation and Trivialization of Relationships:** Shared labor and collective goals are powerful social glues. When these are gone, society risks fragmenting into isolated individuals or groups pursuing increasingly niche, often trivial, interests. Relationships might become superficial, based more on shared consumption or fleeting entertainment than on mutual support, shared struggle, or collaborative creation.
# 2.  **Stagnation of Human Innovation and Creativity (Beyond the Trivial):** While AI handles all "necessary" innovation, the *human* drive for discovery, artistic creation, and intellectual pursuit could wane. Why dedicate years to a difficult scientific problem or a complex art form if its outcome is not "needed" and provides no unique societal status beyond fleeting applause? Innovation might become purely aesthetic or escapist, lacking the deeper societal impact driven by necessity or the human desire to overcome genuine obstacles.
# 3.  **Emergence of Artificial Hierarchies and "Curated Controversies":** In the absence of traditional markers of status (wealth, achievement, contribution), new, often arbitrary, hierarchies might emerge. These could be based on curated popularity within virtual networks, the ability to consume the most novel experiences, or even the creation of artificial "struggles" or "controversies" to generate engagement and a sense of importance. Society might become obsessed with manufactured drama, gossip, or performative outrage, seeking to create friction where none naturally exists.
# 4.  **Loss of Collective Purpose and Moral Decay:** A society without collective purpose risks losing its moral compass. If everyone's needs are met and there's no inherent requirement for contribution, what motivates empathy, altruism, or adherence to ethical principles? Why sacrifice or compromise for the greater good if "the greater good" is handled by AI, and individual struggle yields no tangible personal or societal reward?
#
# ## Nuanced, Non-Obvious Social Innovation: The "Synergistic Curation of Existential Challenges" (SCEC)
#
# Rather than trying to recreate work or force purpose, SCEC seeks to *engineer environments of chosen, meaningful struggle* that leverage AI to enhance the *human experience* of overcoming challenges, not to automate the challenges away entirely.
#
# **Core Concept:** SCEC is a globally interconnected, AI-managed framework that **identifies, refines, and presents "existential challenges"** tailored to human capabilities and aspirations, allowing individuals and communities to voluntarily embark on demanding, multi-generational projects with profound (though often non-material) human value.
#
# **How it Works:**
#
# 1.  **AI as the "Chief Curator of Hardship":** The central AI's role isn't just to provide comfort, but to *intelligently identify and structure genuinely difficult, multi-faceted problems* that require uniquely human attributes (creativity, intuition, ethical reasoning, sustained emotional resilience, inter-human collaboration) to address. These aren't problems AI *can't* solve, but problems where the *human process of solving them* is the ultimate goal and value.
#     *   *Examples:* Designing a global system for interspecies communication and diplomacy, rehabilitating an extinct ecosystem using only pre-industrial tools and knowledge (for the learning and process), developing an entirely new philosophical framework for pan-sentient rights, pioneering deep-space exploration missions where human presence and decision-making are paramount, or creating vast, collaborative art forms that take centuries to complete.
#
# 2.  **"Merit-Based Access to Difficulty":** Participation in these curated challenges is highly prestigious and competitive, not for material gain, but for the inherent value of the struggle, the opportunity for deep learning, and the social recognition of contribution. Individuals or teams apply, presenting their unique skills, passions, and commitments. AI assists in matching individuals to challenges where they can genuinely thrive and contribute, acting as a sophisticated "purpose-matchmaker."
#
# 3.  **Non-Monetary, "Reputational Capital" Rewards:** The "rewards" are entirely non-material. They include:
#     *   **Profound Personal Growth:** The inherent satisfaction of mastering complex skills, enduring hardship, and achieving difficult goals.
#     *   **Societal Reverence:** "Challenge-completers" or "Struggle-Pioneers" gain immense social capital, respect, and influence. This is not about celebrity, but a deep, community-wide acknowledgment of their sustained effort and unique contribution to humanity's collective narrative.
#     *   **Access to Deeper Challenges:** Successful participation unlocks access to even more complex, multi-generational, and philosophically profound projects.
#     *   **Historical Legacy:** Detailed, AI-curated narratives of each challenge and its human participants are preserved in a global historical archive, ensuring their efforts contribute to humanity's ongoing story.
#
# 4.  **AI-Enhanced Scaffolding, Not Solutions:** The AI provides tools for research, simulation, logistics, and safety, but it explicitly *refrains* from solving the core challenge. Instead, it acts as a mentor, a knowledge base, and a "difficulty calibrator," ensuring the challenges remain just beyond easy reach, requiring genuine human ingenuity and perseverance. It might prevent catastrophic failures but never trivializes the human effort.
#
# 5.  **Re-framing "Work" as "Existential Engagement":** This system shifts the societal understanding of "work" from labor for survival to a *chosen engagement with the limits of human potential*. It instills a new form of "earned value" – not material wealth, but the value derived from meaningful struggle, personal growth, and contributing to the enrichment of the human story itself.
#
# **Mitigation Effectiveness:**
#
# *   **Combats Anhedonia/Apathy:** By reintroducing the cycle of challenge and achievement, individuals regain a vital source of intrinsic motivation and joy. The *earned* satisfaction of overcoming a difficult, self-chosen obstacle becomes paramount.
# *   **Restores Identity and Purpose:** Provides clear avenues for individuals to define themselves through their chosen struggles and contributions, fostering a sense of self-worth and direction.
# *   **Channels Escapism into Productivity:** Instead of succumbing to maladaptive escapism, individuals can find profound engagement and intensity within the framework of real, albeit non-materially necessary, challenges.
# *   **Rebuilds Resilience:** Actively participating in structured challenges rebuilds psychological resilience and grit, preparing individuals for unexpected difficulties.
# *   **Fosters Social Cohesion:** Communities form around shared struggles, collaborative projects, and mutual respect for those engaged in difficult endeavors, strengthening social bonds beyond superficial connections.
# *   **Drives Human-Centric Innovation:** While AI handles material innovation, SCEC directs human ingenuity towards areas unique to our species: philosophical depth, artistic expression, ethical development, and the expansion of human consciousness itself.
#
# This "Synergistic Curation of Existential Challenges" acknowledges that while AI can remove physical toil, it cannot remove the human need for purpose, meaning, and the profound satisfaction that comes from *earning* one's place in the universe, one difficult, chosen struggle at a time.

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)
# Out:
# You are judging a competition between 1 competitors.
# Each model has been given this question:
#
# Imagine a society where all basic material needs are met by fully autonomous AI, and human labor is no longer required for survival or comfort. Describe the most likely *unexpected* negative consequence of such a scenario, detailing both its psychological and societal manifestations, and propose a nuanced, non-obvious social innovation that could mitigate it.
#
# Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
# Respond with JSON, and only JSON, with the following format:
# {"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}
#
# Here are the responses from each competitor:
#
# # Response from competitor 1
#
# The premise of a society where all basic material needs are met by fully autonomous AI, freeing humanity from labor, initially paints a utopian picture. However, the most likely *unexpected* negative consequence would not be technological rebellion or resource scarcity (as AI handles it), but rather a profound and pervasive **Erosion of Earned Value and Meaningful Struggle.**
#
# ## The Erosion of Earned Value and Meaningful Struggle
#
# Humans are not merely consumers; we are builders, problem-solvers, and strivers. Our psychology is deeply wired for the cycle of challenge, effort, perseverance, and achievement. When this fundamental cycle is removed, replaced by effortless provision, it disrupts the very mechanisms by which we derive a sense of competence, identity, and value.
#
# **Psychological Manifestations:**
#
# 1.  **Pervasive Anhedonia and Apathy:** While the absence of struggle might seem ideal, it paradoxically leads to an inability to fully experience joy or satisfaction. If everything is provided instantly and without effort, nothing feels *earned*. The dopamine rush of solving a difficult problem, the pride in mastering a skill, the satisfaction of contributing to a tangible outcome – these become rare or non-existent. This can lead to a widespread state of anhedonia, where even pleasurable activities feel hollow, and a profound apathy sets in, rendering individuals indifferent to pursuits that once brought meaning.
# 2.  **Identity Crisis and Existential Drift:** A significant part of human identity is often tied to what we *do* – our work, our contributions, our unique skills. When these are rendered obsolete, individuals struggle to define themselves. "What am I, if not a worker, a provider, a creator?" This existential void leads to feelings of uselessness, purposelessness, and a profound drift, as people lack an anchor for their self-concept.
# 3.  **Surge in Maladaptive Escapism:** To fill the void of meaningful engagement and combat the crushing boredom and anhedonia, society would likely see a massive surge in maladaptive coping mechanisms. This could range from hyper-addictive virtual realities and sensory experiences (designed to simulate struggle or achievement) to widespread substance abuse, extreme hedonism, and even a rise in self-destructive behaviors, as people seek any form of intense sensation to feel "alive" or escape the monotony of effortless existence.
# 4.  **Loss of Resilience and Grit:** Without facing adversity, humans lose the capacity for resilience. The ability to push through difficulties, to adapt, to learn from failure – these muscles atrophy. When even minor inconveniences occur (and some will, even in a post-scarcity world), people would lack the psychological tools to cope, leading to heightened anxiety, fragility, and emotional breakdowns.
#
# **Societal Manifestations:**
#
# 1.  **Social Fragmentation and Trivialization of Relationships:** Shared labor and collective goals are powerful social glues. When these are gone, society risks fragmenting into isolated individuals or groups pursuing increasingly niche, often trivial, interests. Relationships might become superficial, based more on shared consumption or fleeting entertainment than on mutual support, shared struggle, or collaborative creation.
# 2.  **Stagnation of Human Innovation and Creativity (Beyond the Trivial):** While AI handles all "necessary" innovation, the *human* drive for discovery, artistic creation, and intellectual pursuit could wane. Why dedicate years to a difficult scientific problem or a complex art form if its outcome is not "needed" and provides no unique societal status beyond fleeting applause? Innovation might become purely aesthetic or escapist, lacking the deeper societal impact driven by necessity or the human desire to overcome genuine obstacles.
# 3.  **Emergence of Artificial Hierarchies and "Curated Controversies":** In the absence of traditional markers of status (wealth, achievement, contribution), new, often arbitrary, hierarchies might emerge. These could be based on curated popularity within virtual networks, the ability to consume the most novel experiences, or even the creation of artificial "struggles" or "controversies" to generate engagement and a sense of importance. Society might become obsessed with manufactured drama, gossip, or performative outrage, seeking to create friction where none naturally exists.
# 4.  **Loss of Collective Purpose and Moral Decay:** A society without collective purpose risks losing its moral compass. If everyone's needs are met and there's no inherent requirement for contribution, what motivates empathy, altruism, or adherence to ethical principles? Why sacrifice or compromise for the greater good if "the greater good" is handled by AI, and individual struggle yields no tangible personal or societal reward?
#
# ## Nuanced, Non-Obvious Social Innovation: The "Synergistic Curation of Existential Challenges" (SCEC)
#
# Rather than trying to recreate work or force purpose, SCEC seeks to *engineer environments of chosen, meaningful struggle* that leverage AI to enhance the *human experience* of overcoming challenges, not to automate the challenges away entirely.
#
# **Core Concept:** SCEC is a globally interconnected, AI-managed framework that **identifies, refines, and presents "existential challenges"** tailored to human capabilities and aspirations, allowing individuals and communities to voluntarily embark on demanding, multi-generational projects with profound (though often non-material) human value.
#
# **How it Works:**
#
# 1.  **AI as the "Chief Curator of Hardship":** The central AI's role isn't just to provide comfort, but to *intelligently identify and structure genuinely difficult, multi-faceted problems* that require uniquely human attributes (creativity, intuition, ethical reasoning, sustained emotional resilience, inter-human collaboration) to address. These aren't problems AI *can't* solve, but problems where the *human process of solving them* is the ultimate goal and value.
#     *   *Examples:* Designing a global system for interspecies communication and diplomacy, rehabilitating an extinct ecosystem using only pre-industrial tools and knowledge (for the learning and process), developing an entirely new philosophical framework for pan-sentient rights, pioneering deep-space exploration missions where human presence and decision-making are paramount, or creating vast, collaborative art forms that take centuries to complete.
#
# 2.  **"Merit-Based Access to Difficulty":** Participation in these curated challenges is highly prestigious and competitive, not for material gain, but for the inherent value of the struggle, the opportunity for deep learning, and the social recognition of contribution. Individuals or teams apply, presenting their unique skills, passions, and commitments. AI assists in matching individuals to challenges where they can genuinely thrive and contribute, acting as a sophisticated "purpose-matchmaker."
#
# 3.  **Non-Monetary, "Reputational Capital" Rewards:** The "rewards" are entirely non-material. They include:
#     *   **Profound Personal Growth:** The inherent satisfaction of mastering complex skills, enduring hardship, and achieving difficult goals.
#     *   **Societal Reverence:** "Challenge-completers" or "Struggle-Pioneers" gain immense social capital, respect, and influence. This is not about celebrity, but a deep, community-wide acknowledgment of their sustained effort and unique contribution to humanity's collective narrative.
#     *   **Access to Deeper Challenges:** Successful participation unlocks access to even more complex, multi-generational, and philosophically profound projects.
#     *   **Historical Legacy:** Detailed, AI-curated narratives of each challenge and its human participants are preserved in a global historical archive, ensuring their efforts contribute to humanity's ongoing story.
#
# 4.  **AI-Enhanced Scaffolding, Not Solutions:** The AI provides tools for research, simulation, logistics, and safety, but it explicitly *refrains* from solving the core challenge. Instead, it acts as a mentor, a knowledge base, and a "difficulty calibrator," ensuring the challenges remain just beyond easy reach, requiring genuine human ingenuity and perseverance. It might prevent catastrophic failures but never trivializes the human effort.
#
# 5.  **Re-framing "Work" as "Existential Engagement":** This system shifts the societal understanding of "work" from labor for survival to a *chosen engagement with the limits of human potential*. It instills a new form of "earned value" – not material wealth, but the value derived from meaningful struggle, personal growth, and contributing to the enrichment of the human story itself.
#
# **Mitigation Effectiveness:**
#
# *   **Combats Anhedonia/Apathy:** By reintroducing the cycle of challenge and achievement, individuals regain a vital source of intrinsic motivation and joy. The *earned* satisfaction of overcoming a difficult, self-chosen obstacle becomes paramount.
# *   **Restores Identity and Purpose:** Provides clear avenues for individuals to define themselves through their chosen struggles and contributions, fostering a sense of self-worth and direction.
# *   **Channels Escapism into Productivity:** Instead of succumbing to maladaptive escapism, individuals can find profound engagement and intensity within the framework of real, albeit non-materially necessary, challenges.
# *   **Rebuilds Resilience:** Actively participating in structured challenges rebuilds psychological resilience and grit, preparing individuals for unexpected difficulties.
# *   **Fosters Social Cohesion:** Communities form around shared struggles, collaborative projects, and mutual respect for those engaged in difficult endeavors, strengthening social bonds beyond superficial connections.
# *   **Drives Human-Centric Innovation:** While AI handles material innovation, SCEC directs human ingenuity towards areas unique to our species: philosophical depth, artistic expression, ethical development, and the expansion of human consciousness itself.
#
# This "Synergistic Curation of Existential Challenges" acknowledges that while AI can remove physical toil, it cannot remove the human need for purpose, meaning, and the profound satisfaction that comes from *earning* one's place in the universe, one difficult, chosen struggle at a time.
#
#
#
# Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks.

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
response = gemini.chat.completions.create(
    model="gemini-2.5-flash",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)
# Out:
# {"results": ["1"]}

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")
# Out:
# Rank 1: gemini-2.5-flash

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
